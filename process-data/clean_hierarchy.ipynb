# %%
import json

# %%
first_time = True

# %%
# read json file
if first_time:
    with open('../data/hierarchy_unions_v8.json') as f:
        data = json.load(f)
else:
    with open('../data/hierarchy_unions_v9.json') as f:
        data = json.load(f)

# %%
copy_data = data.copy()
to_remove = []  # List to store items to remove from Independent
unmatched_unions = []  # Track unions that don't match any condition

for union in copy_data:

    if copy_data[union]["afl-cio"] == True:
        continue

    matched = False  # Flag to track if a union matches any condition
    
    if "operating engineers" in union or "union of operatingengineers" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "iuoe"
        matched = True
    
    elif "security, police and fire professionals" in union or "security, police, and fire professionals" in union and "spfpa" in union or "security, police & fire professionals" in union or "security, police and fire association" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "spfpa"
        matched = True
    
    elif "brotherhood of electrical workers" in union or "ibew" in union or "brotherhood electrical workers" in union or "international brootherhood of electrical workers" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "ibew"
        matched = True
    
    elif "laborers' international union of north america" in union or "laborers international union of north america" in union or "laborers'" in union or "laborer's" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "liuna"
        matched = True
    
    elif "sheet metal, air, rail and transportation" in union or "sheet metal, air, rail, and transportation" in union or "association of sheet metal" in union or "(smart)" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "smart"
        matched = True
    
    elif "heat and frost insulators and allied workers" in union or "heat & frost insulators" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "insulators"
        matched = True
    
    elif "amalgamated transit union" in union or "amalgamated transit workers" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "atu"
        matched = True
    
    elif "united government security officers of america" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "ugsoa"
        matched = True
    
    elif "american guild of musical artists" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "agma"
        matched = True
    
    elif "american federation of state, county & municipal employees" in union or "state, county and municipal employees" in union or "american federation of state, county, and municipal employees" in union or "afscme" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "afscme"
        matched = True
    
    elif "workers united" in union or "worker united" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "seiu"
        matched = True

    elif "machinists & aerospace workers" in union or "machinist and aerospace workers" in union or "machinists and aerospace workers" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "iam"
        matched = True

    elif "alliance of theatrical stage employees" in union or "i.a.t.s.e" in union or "theatrical & stage employees" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "iatse"
        matched = True

    elif "united food and commercial workers" in union or "united food & commercial workers" in union or "food and commercial worker" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "ufcw"
        matched = True

    elif "national union of nuclear security officers" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "leos-pba"
        matched = True

    elif "bricklayers and allied craftworkers" in union or "international union of bricklayers" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "bac"
        matched = True

    elif "office and professional employees" in union or "office & professional employees" in union or "opeiu" in union or "office of professional employees" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "opeiu"
        matched = True
    
    elif "iupat" in union or "painters and allied trades" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "iupat"
        matched = True

    elif "u.a.w." in union or "united auto workers" in union or "(uaw)" in union or "uaw" in union or "united automobile, aerospace and agricultural" in union or "united automobile, aerospace & agricultural" in union or "automobile. aerospace and agricultural" in union or "united automobile, aerospace andagricultural" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "uaw"
        matched = True

    elif "s.e.i.u" in union or "seiu" in union or "service employees international" in union or "service employees' international union" in union or "service employees internal union" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "seiu"
        matched = True

    elif "truck drivers and helpers" in union or "i.b.t." in union or "teamster" in union or "drivers, helpers, and warehousemen" in union or "drivers, warehousemen and helpers" in union or "general drivers, warehousemen and helpers" in union or "general drivers & helpers" in union or "general drivers and helpers" in union or "drivers, warehousemen & helpers" in union or "drivers, warehousemen, and helpers" in union or "drivers, warehousemen and helpers" in union or "general drivers and helpers union" in union or "ibt" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "ibt"
        matched = True

    elif "longshore & warehouse" in union or "inlandboatmen" in union or "longshore and warehouse" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "ilwu"
        matched = True

    elif "sag-aftra" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "sag-aftra"
        matched = True

    elif "painters & allied trades" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "iupat"
        matched = True

    elif "plumbers and steamfitters" in union or "plumbers, steamfitters" in union or "plumbers, pipefitters" in union or "plumbers and pipefitters" in union or "journeymen & apprentices of the plumbing" in union or "journeymen and apprentices of the plumbing and pipe fitting industry" in union or "pipefitters" in union or "sprinkler fitters" in union or "journeymen and apprentices of the plumbing and pipefitting" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "ua"
        matched = True

    elif "retail, wholesale, and department store" in union or "wholesale and department store" in union or "wholeseale department store union" in union or "rwsdu" in union or "retail, wholesale & department store" in union or "retail, wholesale and department store" in union or "united food & commercial" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "ufcw"
        matched = True

    elif "united steel" in union or "usw" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "usw"
        matched = True

    elif "bakery, confectionery, tobacco" in union or "bakery, confectionary, tobacco" in union or "bakery confectionery tobacco" in union or "bakery confectionary tobacco" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "bctgm"
        matched = True

    elif "enforcement officers" in union or "leos-pba" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "leos-pba"
        matched = True

    elif "association of emt's and paramedics" in union or "iaep" in union or "international association of emts & paramedics" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "iaep"
        matched = True

    elif "communications workers of america" in union or "communication workers of america" in union or "news guild" in union or "cwa" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "cwa"
        matched = True

    elif "union of special police officers" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "nuspo"
        matched = True

    elif "textile processors, service trades health care, professional and technical employees" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "uia"
        matched = True

    elif "construction trades & industrial employees" in union or "construction trades and industrial employees" in union or "u.c.t.i.e." in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "uctie"
        matched = True

    elif "garage employees" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "ibt"
        matched = True

    elif "united workers of america" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "uwa"
        matched = True

    elif "national air traffic controllers association" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "natca"
        matched = True
    
    elif "international association of fire fighters" in union or "international association of firefighters" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "iaff"
        matched = True

    elif "spfpa" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "spfpa"
        matched = True

    elif "league of international federated employees" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "life"
        matched = True

    elif "association of teachers training actors" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "aft"
        matched = True

    elif "western pulp and paper workers" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "awppw"
        matched = True

    elif "national allied workers union" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "nawu"
        matched = True

    elif "fraternity of american protective officers" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "fapo"
        matched = True

    elif "ucfw" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "ufcw"
        matched = True

    elif "transportation, production, & warehouse employees" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "npwu"
        matched = True

    elif "utility workers union" in union or "utiltiy workers union" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "uwua"
        matched = True

    elif "journeymen and allied trades" in union or "united service workers union" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "uswu"
        matched = True

    elif "(ue)" in union or "united electrical, radio and machine workers" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "ue"
        matched = True

    elif "transport workers union" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "twu"
        matched = True

    elif "industrial workers of the world" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "iww"
        matched = True
    
    elif "national nurses united" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "nnu"
        matched = True

    elif "international chemical workers union council" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "icwuc"
        matched = True

    elif "eastern atlantic states regional council of carpenters" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "easrcc"
        matched = True

    elif "international brotherhood of trade unions" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "ibtu"
        matched = True

    elif "national capital union for security officers" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "ncufso"
        matched = True

    elif "fraternal association of professional paramedics" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "fapp"
        matched = True

    elif "united security forces of america, international union" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "usfaiu"
        matched = True

    elif "international guards union of america" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "igua"
        matched = True

    elif "iron workers regional" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "ironworkers"
        matched = True

    elif "operative plasterers' & cement masons' international association" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "opcmia"
        matched = True

    elif "united production workers union" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "upwu"
        matched = True
    
    elif "gas workers" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "uwua"
        matched = True

    elif "american federation of teachers" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "aft"
        matched = True

    elif "union of american physicians and dentists" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "uapd"
        matched = True

    elif "cabinet makers, millmen and industrial carpenters" in union or "brotherhood of carpenters" in union:
        copy_data[union]["afl-cio"] = False
        copy_data[union]["main_union"] = "carpenters"
        matched = True

    elif "boilermakers" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "ibb"
        matched = True

    elif "international longshoremen's association" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "ila"
        matched = True

    elif "unite here" in union:
        copy_data[union]["afl-cio"] = True
        copy_data[union]["main_union"] = "unite here"
        matched = True
    
copy_data
# Out:
# {'national nurses organizing committee (nnoc) - texas/national nurses united (nnu)': {'afl-cio': True,
#   'main_union': 'nnu',
#   'district': None,
#   'local': None},
#  'national nurses organizing committee-florida/nnu': {'afl-cio': True,
#   'main_union': 'nnu',
#   'district': None,
#   'local': None},
#  'national nurses organizing committee/ national nurses united, afl-cio (nnoc/nnu)': {'afl-cio': True,
#   'main_union': 'nnu',
#   'district': None,
#   'local': None},
#  'national nurses organizing committee-missouri/national nurses united (nnoc-mo/nnu)': {'afl-cio': True,
#   'main_union': 'nnu',
#   'district': None,
#   'local': None},
#  'national nurses organizing committee (nnoc) - texas/nnu': {'afl-cio': True,
#   'main_union': 'nnu',
#   'district': None,
#   'local': None},
#  'national nurses organizing committee - louisiana/national nurses united': {'afl-cio': True,
#   'main_union': 'nnu',
#   'district': None,
#   'local': None},
# ...

# %% [markdown]
# Fix afl-cio association for some main unions

# %%
for union in copy_data:
    
    if copy_data[union]["main_union"] != None and "afl-cio" in copy_data[union]["main_union"]:
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "iuoe":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "spfpa":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "ibew":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "liuna":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "smart":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "insulators":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "atu":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "ugsoa":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "agma":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "afscme":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "seiu":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "iam":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "iatse":
        copy_data[union]["afl-cio"] = True
    
    elif copy_data[union]["main_union"] == "ufcw":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "leos-pba":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "bac":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "opeiu":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "iupat":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "uaw":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "ibt":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "ilwu":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "sag-aftra":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "iupat":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "ua":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "usw":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "bctgm":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "iaep":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "cwa":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "nuspo":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "uia":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "uctie":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "uwa":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "natca":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "iaff":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "spfpa":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "life":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "aft":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "awppw":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "nawu":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "fapo":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "ufcw":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "npwu":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "uwua":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "uswu":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "ue":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "twu":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "iww":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "nnu":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "icwuc":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "easrcc":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "ibtu":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "ncufso":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "fapp":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "usfaiu":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "igua":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "ironworkers":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "opcmia":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "upwu":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "uwua":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "aft":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "uapd":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "carpenters":
        copy_data[union]["afl-cio"] = False

    elif copy_data[union]["main_union"] == "ibb":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "ila":
        copy_data[union]["afl-cio"] = True

    elif copy_data[union]["main_union"] == "unite here":
        copy_data[union]["afl-cio"] = True

# %%
# export to json file
with open('../data/hierarchy_unions_v9.json', 'w') as f:
    json.dump(data, f, indent=4)
